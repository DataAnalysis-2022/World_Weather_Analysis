# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=73f25366873142d3856f3ee367e40ad3

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
#lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    print("set =", set_count)
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(1)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        #print(city_weather)
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descript = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_descript,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# set = 1
# Processing Record 1 of Set 1 | severo-kurilsk
# set = 1
# Processing Record 2 of Set 1 | busselton
# set = 1
# Processing Record 3 of Set 1 | hobart
# set = 1
# Processing Record 4 of Set 1 | killin
# set = 1
# Processing Record 5 of Set 1 | padang
# set = 1
# Processing Record 6 of Set 1 | petropavlovsk-kamchatskiy
# set = 1
# Processing Record 7 of Set 1 | mahebourg
# set = 1
# Processing Record 8 of Set 1 | bredasdorp
# set = 1
# Processing Record 9 of Set 1 | barrow
# set = 1
# Processing Record 10 of Set 1 | provideniya
# set = 1
# Processing Record 11 of Set 1 | punta arenas
# set = 1
# Processing Record 12 of Set 1 | bubaque
# set = 1
# Processing Record 13 of Set 1 | ambanja
# set = 1
# Processing Record 14 of Set 1 | hirado
# set = 1
# Processing Record 15 of Set 1 | san luis
# set = 1
# Processing Record 16 of Set 1 | fraserburgh
# set = 1
# Processing Record 17 of Set 1 | la grande
# set = 1
# Processing Record 18 of Set 1 | morondava
# set = 1
# Processing Record 19 of Set 1 | nanortalik
# set = 1
# Processing Record 20 of Set 1 | la trinidad
# set = 1
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# set = 1
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# set = 1
# Processing Record 23 of Set 1 | magdagachi
# set = 1
# Processing Record 24 of Set 1 | ilulissat
# set = 1
# Processing Record 25 of Set 1 | buala
# set = 1
# Processing Record 26 of Set 1 | mareeba
# set = 1
# Processing Record 27 of Set 1 | erzurum
# set = 1
# Processing Record 28 of Set 1 | viedma
# set = 1
# Processing Record 29 of Set 1 | vaini
# set = 1
# Processing Record 30 of Set 1 | palana
# set = 1
# Processing Record 31 of Set 1 | longyearbyen
# set = 1
# Processing Record 32 of Set 1 | laguna
# set = 1
# Processing Record 33 of Set 1 | luanda
# set = 1
# Processing Record 34 of Set 1 | mae hong son
# set = 1
# Processing Record 35 of Set 1 | ushuaia
# set = 1
# Processing Record 36 of Set 1 | gunnedah
# set = 1
# Processing Record 37 of Set 1 | kailua
# set = 1
# Processing Record 38 of Set 1 | carnarvon
# set = 1
# Processing Record 39 of Set 1 | riachao
# set = 1
# Processing Record 40 of Set 1 | avarua
# set = 1
# Processing Record 41 of Set 1 | kodiak
# set = 1
# Processing Record 42 of Set 1 | ust-tsilma
# set = 1
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# set = 1
# Processing Record 44 of Set 1 | santa isabel
# set = 1
# Processing Record 45 of Set 1 | lemesos
# City not found. Skipping...
# set = 1
# Processing Record 46 of Set 1 | sioux lookout
# set = 1
# Processing Record 47 of Set 1 | albany
# set = 1
# Processing Record 48 of Set 1 | cayenne
# set = 1
# Processing Record 49 of Set 1 | qaanaaq
# set = 1
# Processing Record 50 of Set 1 | envira
# set = 1
# Processing Record 1 of Set 2 | sola
# set = 2
# Processing Record 2 of Set 2 | grand gaube
# set = 2
# Processing Record 3 of Set 2 | yellowknife
# set = 2
# Processing Record 4 of Set 2 | nador
# set = 2
# Processing Record 5 of Set 2 | rikitea
# set = 2
# Processing Record 6 of Set 2 | inhambane
# set = 2
# Processing Record 7 of Set 2 | vila
# set = 2
# Processing Record 8 of Set 2 | butaritari
# set = 2
# Processing Record 9 of Set 2 | kaputa
# set = 2
# Processing Record 10 of Set 2 | saskylakh
# set = 2
# Processing Record 11 of Set 2 | cape town
# set = 2
# Processing Record 12 of Set 2 | norman wells
# set = 2
# Processing Record 13 of Set 2 | broken hill
# set = 2
# Processing Record 14 of Set 2 | portland
# set = 2
# Processing Record 15 of Set 2 | victoria
# set = 2
# Processing Record 16 of Set 2 | mar del plata
# set = 2
# Processing Record 17 of Set 2 | castro
# set = 2
# Processing Record 18 of Set 2 | tiznit
# set = 2
# Processing Record 19 of Set 2 | lavrentiya
# set = 2
# Processing Record 20 of Set 2 | codrington
# set = 2
# Processing Record 21 of Set 2 | nurota
# set = 2
# Processing Record 22 of Set 2 | atuona
# set = 2
# Processing Record 23 of Set 2 | machico
# set = 2
# Processing Record 24 of Set 2 | bambanglipuro
# set = 2
# Processing Record 25 of Set 2 | hithadhoo
# set = 2
# Processing Record 26 of Set 2 | hermanus
# set = 2
# Processing Record 27 of Set 2 | gambela
# set = 2
# Processing Record 28 of Set 2 | kaa-khem
# set = 2
# Processing Record 29 of Set 2 | talara
# set = 2
# Processing Record 30 of Set 2 | makat
# set = 2
# Processing Record 31 of Set 2 | lagoa
# set = 2
# Processing Record 32 of Set 2 | mount gambier
# set = 2
# Processing Record 33 of Set 2 | ancud
# set = 2
# Processing Record 34 of Set 2 | starosubkhangulovo
# set = 2
# Processing Record 35 of Set 2 | nago
# set = 2
# Processing Record 36 of Set 2 | chokurdakh
# set = 2
# Processing Record 37 of Set 2 | port alfred
# set = 2
# Processing Record 38 of Set 2 | pevek
# set = 2
# Processing Record 39 of Set 2 | straumen
# set = 2
# Processing Record 40 of Set 2 | sabang
# set = 2
# Processing Record 41 of Set 2 | barentsburg
# City not found. Skipping...
# set = 2
# Processing Record 42 of Set 2 | vardo
# set = 2
# Processing Record 43 of Set 2 | alotau
# City not found. Skipping...
# set = 2
# Processing Record 44 of Set 2 | tasiilaq
# set = 2
# Processing Record 45 of Set 2 | sorong
# set = 2
# Processing Record 46 of Set 2 | arraial do cabo
# set = 2
# Processing Record 47 of Set 2 | iqaluit
# set = 2
# Processing Record 48 of Set 2 | melfort
# set = 2
# Processing Record 49 of Set 2 | mataura
# set = 2
# Processing Record 50 of Set 2 | asfi
# set = 2
# Processing Record 1 of Set 3 | moron
# set = 3
# Processing Record 2 of Set 3 | georgetown
# set = 3
# Processing Record 3 of Set 3 | duz
# City not found. Skipping...
# set = 3
# Processing Record 4 of Set 3 | kirkwood
# set = 3
# Processing Record 5 of Set 3 | jamestown
# set = 3
# Processing Record 6 of Set 3 | bondo
# set = 3
# Processing Record 7 of Set 3 | mackay
# set = 3
# Processing Record 8 of Set 3 | amderma
# City not found. Skipping...
# set = 3
# Processing Record 9 of Set 3 | shimoda
# set = 3
# Processing Record 10 of Set 3 | lyubeshiv
# City not found. Skipping...
# set = 3
# Processing Record 11 of Set 3 | christiansfeld
# set = 3
# Processing Record 12 of Set 3 | ust-maya
# set = 3
# Processing Record 13 of Set 3 | thompson
# set = 3
# Processing Record 14 of Set 3 | emba
# set = 3
# Processing Record 15 of Set 3 | liverpool
# set = 3
# Processing Record 16 of Set 3 | knysna
# set = 3
# Processing Record 17 of Set 3 | freeport
# set = 3
# Processing Record 18 of Set 3 | komsomolskiy
# set = 3
# Processing Record 19 of Set 3 | bengkulu
# set = 3
# Processing Record 20 of Set 3 | san juan bautista
# set = 3
# Processing Record 21 of Set 3 | tsihombe
# City not found. Skipping...
# set = 3
# Processing Record 22 of Set 3 | yumen
# set = 3
# Processing Record 23 of Set 3 | roald
# set = 3
# Processing Record 24 of Set 3 | klaksvik
# set = 3
# Processing Record 25 of Set 3 | toliary
# City not found. Skipping...
# set = 3
# Processing Record 26 of Set 3 | katsuura
# set = 3
# Processing Record 27 of Set 3 | marcona
# City not found. Skipping...
# set = 3
# Processing Record 28 of Set 3 | carballo
# set = 3
# Processing Record 29 of Set 3 | vila franca do campo
# set = 3
# Processing Record 30 of Set 3 | monte patria
# set = 3
# Processing Record 31 of Set 3 | saint-philippe
# set = 3
# Processing Record 32 of Set 3 | broome
# set = 3
# Processing Record 33 of Set 3 | rabo de peixe
# set = 3
# Processing Record 34 of Set 3 | vuyyuru
# set = 3
# Processing Record 35 of Set 3 | sfantu gheorghe
# set = 3
# Processing Record 36 of Set 3 | kaitangata
# set = 3
# Processing Record 37 of Set 3 | warrnambool
# set = 3
# Processing Record 38 of Set 3 | naifaru
# set = 3
# Processing Record 39 of Set 3 | bethel
# set = 3
# Processing Record 40 of Set 3 | hilo
# set = 3
# Processing Record 41 of Set 3 | saint george
# set = 3
# Processing Record 42 of Set 3 | nikolskoye
# set = 3
# Processing Record 43 of Set 3 | new norfolk
# set = 3
# Processing Record 44 of Set 3 | sidi ali
# set = 3
# Processing Record 45 of Set 3 | dikson
# set = 3
# Processing Record 46 of Set 3 | buraydah
# set = 3
# Processing Record 47 of Set 3 | orotukan
# set = 3
# Processing Record 48 of Set 3 | narsaq
# set = 3
# Processing Record 49 of Set 3 | uribia
# set = 3
# Processing Record 50 of Set 3 | molchanovo
# set = 3
# Processing Record 1 of Set 4 | puerto ayora
# set = 4
# Processing Record 2 of Set 4 | kapaa
# set = 4
# Processing Record 3 of Set 4 | siteki
# set = 4
# Processing Record 4 of Set 4 | khatanga
# set = 4
# Processing Record 5 of Set 4 | mercedes
# set = 4
# Processing Record 6 of Set 4 | kahului
# set = 4
# Processing Record 7 of Set 4 | kemijarvi
# set = 4
# Processing Record 8 of Set 4 | upernavik
# set = 4
# Processing Record 9 of Set 4 | kavieng
# set = 4
# Processing Record 10 of Set 4 | tumannyy
# City not found. Skipping...
# set = 4
# Processing Record 11 of Set 4 | sao joao da barra
# set = 4
# Processing Record 12 of Set 4 | luderitz
# set = 4
# Processing Record 13 of Set 4 | nome
# set = 4
# Processing Record 14 of Set 4 | ijaki
# City not found. Skipping...
# set = 4
# Processing Record 15 of Set 4 | beringovskiy
# set = 4
# Processing Record 16 of Set 4 | faanui
# set = 4
# Processing Record 17 of Set 4 | port elizabeth
# set = 4
# Processing Record 18 of Set 4 | tilichiki
# set = 4
# Processing Record 19 of Set 4 | suksun
# set = 4
# Processing Record 20 of Set 4 | zhigansk
# set = 4
# Processing Record 21 of Set 4 | comodoro rivadavia
# set = 4
# Processing Record 22 of Set 4 | cidreira
# set = 4
# Processing Record 23 of Set 4 | tuktoyaktuk
# set = 4
# Processing Record 24 of Set 4 | half moon bay
# set = 4
# Processing Record 25 of Set 4 | rawlins
# set = 4
# Processing Record 26 of Set 4 | coihaique
# set = 4
# Processing Record 27 of Set 4 | zelenchukskaya
# set = 4
# Processing Record 28 of Set 4 | kruisfontein
# set = 4
# Processing Record 29 of Set 4 | arona
# set = 4
# Processing Record 30 of Set 4 | kolpashevo
# set = 4
# Processing Record 31 of Set 4 | marsh harbour
# set = 4
# Processing Record 32 of Set 4 | bluff
# set = 4
# Processing Record 33 of Set 4 | riyadh
# set = 4
# Processing Record 34 of Set 4 | panalingaan
# set = 4
# Processing Record 35 of Set 4 | ust-kuyga
# set = 4
# Processing Record 36 of Set 4 | lorengau
# set = 4
# Processing Record 37 of Set 4 | rawson
# set = 4
# Processing Record 38 of Set 4 | brae
# set = 4
# Processing Record 39 of Set 4 | santa ana
# set = 4
# Processing Record 40 of Set 4 | sibut
# set = 4
# Processing Record 41 of Set 4 | grand river south east
# City not found. Skipping...
# set = 4
# Processing Record 42 of Set 4 | hofn
# set = 4
# Processing Record 43 of Set 4 | lolua
# City not found. Skipping...
# set = 4
# Processing Record 44 of Set 4 | dickinson
# set = 4
# Processing Record 45 of Set 4 | te anau
# set = 4
# Processing Record 46 of Set 4 | namibe
# set = 4
# Processing Record 47 of Set 4 | tautira
# set = 4
# Processing Record 48 of Set 4 | kozhva
# set = 4
# Processing Record 49 of Set 4 | krapina
# set = 4
# Processing Record 50 of Set 4 | killybegs
# set = 4
# Processing Record 1 of Set 5 | geraldton
# set = 5
# Processing Record 2 of Set 5 | saint-joseph
# set = 5
# Processing Record 3 of Set 5 | mana
# set = 5
# Processing Record 4 of Set 5 | clyde river
# set = 5
# Processing Record 5 of Set 5 | dalbandin
# set = 5
# Processing Record 6 of Set 5 | ribeira grande
# set = 5
# Processing Record 7 of Set 5 | bahia honda
# set = 5
# Processing Record 8 of Set 5 | ahipara
# set = 5
# Processing Record 9 of Set 5 | kranuan
# set = 5
# Processing Record 10 of Set 5 | pahalgam
# set = 5
# Processing Record 11 of Set 5 | sinnamary
# set = 5
# Processing Record 12 of Set 5 | tura
# set = 5
# Processing Record 13 of Set 5 | homer
# set = 5
# Processing Record 14 of Set 5 | horta
# set = 5
# Processing Record 15 of Set 5 | aragarcas
# set = 5
# Processing Record 16 of Set 5 | kupang
# set = 5
# Processing Record 17 of Set 5 | souillac
# set = 5
# Processing Record 18 of Set 5 | vanimo
# set = 5
# Processing Record 19 of Set 5 | coulihaut
# City not found. Skipping...
# set = 5
# Processing Record 20 of Set 5 | sakakah
# set = 5
# Processing Record 21 of Set 5 | yinchuan
# set = 5
# Processing Record 22 of Set 5 | lakatoro
# set = 5
# Processing Record 23 of Set 5 | ngukurr
# City not found. Skipping...
# set = 5
# Processing Record 24 of Set 5 | east london
# set = 5
# Processing Record 25 of Set 5 | den helder
# set = 5
# Processing Record 26 of Set 5 | saqqez
# set = 5
# Processing Record 27 of Set 5 | mehamn
# set = 5
# Processing Record 28 of Set 5 | maniitsoq
# set = 5
# Processing Record 29 of Set 5 | wanning
# set = 5
# Processing Record 30 of Set 5 | san patricio
# set = 5
# Processing Record 31 of Set 5 | pisco
# set = 5
# Processing Record 32 of Set 5 | la ferte-bernard
# set = 5
# Processing Record 33 of Set 5 | tomatlan
# set = 5
# Processing Record 34 of Set 5 | dibaya
# City not found. Skipping...
# set = 5
# Processing Record 35 of Set 5 | sumbe
# set = 5
# Processing Record 36 of Set 5 | zapolyarnyy
# set = 5
# Processing Record 37 of Set 5 | carutapera
# set = 5
# Processing Record 38 of Set 5 | ormara
# set = 5
# Processing Record 39 of Set 5 | luan
# set = 5
# Processing Record 40 of Set 5 | conceicao do araguaia
# set = 5
# Processing Record 41 of Set 5 | shaoyang
# set = 5
# Processing Record 42 of Set 5 | cesky krumlov
# set = 5
# Processing Record 43 of Set 5 | luksuhin
# set = 5
# Processing Record 44 of Set 5 | gibgos
# set = 5
# Processing Record 45 of Set 5 | payo
# set = 5
# Processing Record 46 of Set 5 | ocos
# set = 5
# Processing Record 47 of Set 5 | airai
# set = 5
# Processing Record 48 of Set 5 | berlevag
# set = 5
# Processing Record 49 of Set 5 | pechora
# set = 5
# Processing Record 50 of Set 5 | vao
# set = 5
# Processing Record 1 of Set 6 | santarem
# set = 6
# Processing Record 2 of Set 6 | lebu
# set = 6
# Processing Record 3 of Set 6 | warrington
# set = 6
# Processing Record 4 of Set 6 | durango
# set = 6
# Processing Record 5 of Set 6 | cabo san lucas
# set = 6
# Processing Record 6 of Set 6 | camacha
# set = 6
# Processing Record 7 of Set 6 | altus
# set = 6
# Processing Record 8 of Set 6 | dok kham tai
# set = 6
# Processing Record 9 of Set 6 | sentyabrskiy
# City not found. Skipping...
# set = 6
# Processing Record 10 of Set 6 | waingapu
# set = 6
# Processing Record 11 of Set 6 | zhangzhou
# set = 6
# Processing Record 12 of Set 6 | champerico
# set = 6
# Processing Record 13 of Set 6 | bilibino
# set = 6
# Processing Record 14 of Set 6 | meulaboh
# set = 6
# Processing Record 15 of Set 6 | praia da vitoria
# set = 6
# Processing Record 16 of Set 6 | phuket
# set = 6
# Processing Record 17 of Set 6 | scarborough
# set = 6
# Processing Record 18 of Set 6 | ponta do sol
# set = 6
# Processing Record 19 of Set 6 | mapiripan
# set = 6
# Processing Record 20 of Set 6 | tiksi
# set = 6
# Processing Record 21 of Set 6 | korla
# set = 6
# Processing Record 22 of Set 6 | torbay
# set = 6
# Processing Record 23 of Set 6 | persan
# set = 6
# Processing Record 24 of Set 6 | nokha
# set = 6
# Processing Record 25 of Set 6 | manono
# set = 6
# Processing Record 26 of Set 6 | samarai
# set = 6
# Processing Record 27 of Set 6 | caravelas
# set = 6
# Processing Record 28 of Set 6 | gorom-gorom
# set = 6
# Processing Record 29 of Set 6 | penzance
# set = 6
# Processing Record 30 of Set 6 | fairbanks
# set = 6
# Processing Record 31 of Set 6 | la ronge
# set = 6
# Processing Record 32 of Set 6 | port macquarie
# set = 6
# Processing Record 33 of Set 6 | gat
# set = 6
# Processing Record 34 of Set 6 | pangody
# set = 6
# Processing Record 35 of Set 6 | constitucion
# set = 6
# Processing Record 36 of Set 6 | pag
# set = 6
# Processing Record 37 of Set 6 | rincon
# set = 6
# Processing Record 38 of Set 6 | sasebo
# set = 6
# Processing Record 39 of Set 6 | mys shmidta
# City not found. Skipping...
# set = 6
# Processing Record 40 of Set 6 | tuatapere
# set = 6
# Processing Record 41 of Set 6 | nizhneyansk
# City not found. Skipping...
# set = 6
# Processing Record 42 of Set 6 | hasaki
# set = 6
# Processing Record 43 of Set 6 | richards bay
# set = 6
# Processing Record 44 of Set 6 | sindor
# set = 6
# Processing Record 45 of Set 6 | pangnirtung
# set = 6
# Processing Record 46 of Set 6 | mizdah
# set = 6
# Processing Record 47 of Set 6 | innisfail
# set = 6
# Processing Record 48 of Set 6 | eyl
# set = 6
# Processing Record 49 of Set 6 | fortuna
# set = 6
# Processing Record 50 of Set 6 | sydney mines
# set = 6
# Processing Record 1 of Set 7 | yermakovskoye
# set = 7
# Processing Record 2 of Set 7 | sychevka
# set = 7
# Processing Record 3 of Set 7 | calbuco
# set = 7
# Processing Record 4 of Set 7 | rocha
# set = 7
# Processing Record 5 of Set 7 | krasnyy chikoy
# set = 7
# Processing Record 6 of Set 7 | midland
# set = 7
# Processing Record 7 of Set 7 | beloha
# set = 7
# Processing Record 8 of Set 7 | khandyga
# set = 7
# Processing Record 9 of Set 7 | chuy
# set = 7
# Processing Record 10 of Set 7 | leningradskiy
# set = 7
# Processing Record 11 of Set 7 | gornouralskiy
# City not found. Skipping...
# set = 7
# Processing Record 12 of Set 7 | guatire
# set = 7
# Processing Record 13 of Set 7 | tankhoy
# set = 7
# Processing Record 14 of Set 7 | kununurra
# set = 7
# Processing Record 15 of Set 7 | katakwi
# set = 7
# Processing Record 16 of Set 7 | payson
# set = 7
# Processing Record 17 of Set 7 | goderich
# set = 7
# Processing Record 18 of Set 7 | lumeje
# set = 7
# Processing Record 19 of Set 7 | husavik
# set = 7
# Processing Record 20 of Set 7 | puerto colombia
# set = 7
# Processing Record 21 of Set 7 | lata
# set = 7
# Processing Record 22 of Set 7 | lompoc
# set = 7
# Processing Record 23 of Set 7 | atambua
# set = 7
# Processing Record 24 of Set 7 | joshimath
# set = 7
# Processing Record 25 of Set 7 | saiha
# set = 7
# Processing Record 26 of Set 7 | watsa
# set = 7
# Processing Record 27 of Set 7 | baykit
# set = 7
# Processing Record 28 of Set 7 | itarema
# set = 7
# Processing Record 29 of Set 7 | yanan
# City not found. Skipping...
# set = 7
# Processing Record 30 of Set 7 | chapleau
# set = 7
# Processing Record 31 of Set 7 | ostrovnoy
# set = 7
# Processing Record 32 of Set 7 | la rioja
# set = 7
# Processing Record 33 of Set 7 | lazaro cardenas
# set = 7
# Processing Record 34 of Set 7 | lebanon
# set = 7
# Processing Record 35 of Set 7 | ahuimanu
# set = 7
# Processing Record 36 of Set 7 | adrar
# set = 7
# Processing Record 37 of Set 7 | keller
# set = 7
# Processing Record 38 of Set 7 | saint-pierre
# set = 7
# Processing Record 39 of Set 7 | candawaga
# City not found. Skipping...
# set = 7
# Processing Record 40 of Set 7 | santa barbara
# set = 7
# Processing Record 41 of Set 7 | pasni
# set = 7
# Processing Record 42 of Set 7 | quelimane
# set = 7
# Processing Record 43 of Set 7 | surok
# set = 7
# Processing Record 44 of Set 7 | dafeng
# set = 7
# Processing Record 45 of Set 7 | fare
# set = 7
# Processing Record 46 of Set 7 | attawapiskat
# City not found. Skipping...
# set = 7
# Processing Record 47 of Set 7 | virginia beach
# set = 7
# Processing Record 48 of Set 7 | astaneh-ye ashrafiyeh
# set = 7
# Processing Record 49 of Set 7 | strezhevoy
# set = 7
# Processing Record 50 of Set 7 | havre-saint-pierre
# set = 7
# Processing Record 1 of Set 8 | lukovetskiy
# set = 8
# Processing Record 2 of Set 8 | kidal
# set = 8
# Processing Record 3 of Set 8 | betong
# set = 8
# Processing Record 4 of Set 8 | kodinsk
# set = 8
# Processing Record 5 of Set 8 | shingu
# set = 8
# Processing Record 6 of Set 8 | teguise
# set = 8
# Processing Record 7 of Set 8 | caucaia
# set = 8
# Processing Record 8 of Set 8 | romny
# set = 8
# Processing Record 9 of Set 8 | nyurba
# set = 8
# Processing Record 10 of Set 8 | aquiraz
# set = 8
# Processing Record 11 of Set 8 | thessalon
# set = 8
# Processing Record 12 of Set 8 | casale monferrato
# set = 8
# Processing Record 13 of Set 8 | ca mau
# set = 8
# Processing Record 14 of Set 8 | uwayl
# City not found. Skipping...
# set = 8
# Processing Record 15 of Set 8 | iberia
# set = 8
# Processing Record 16 of Set 8 | uruzgan
# set = 8
# Processing Record 17 of Set 8 | yarada
# set = 8
# Processing Record 18 of Set 8 | khani
# set = 8
# Processing Record 19 of Set 8 | ryotsu
# set = 8
# Processing Record 20 of Set 8 | riaba
# City not found. Skipping...
# set = 8
# Processing Record 21 of Set 8 | chapais
# set = 8
# Processing Record 22 of Set 8 | mumford
# set = 8
# Processing Record 23 of Set 8 | klyuchevskiy
# set = 8
# Processing Record 24 of Set 8 | colac
# set = 8
# Processing Record 25 of Set 8 | olafsvik
# set = 8
# Processing Record 26 of Set 8 | flinders
# set = 8
# Processing Record 27 of Set 8 | faya
# set = 8
# Processing Record 28 of Set 8 | the valley
# set = 8
# Processing Record 29 of Set 8 | oussouye
# set = 8
# Processing Record 30 of Set 8 | port blair
# set = 8
# Processing Record 31 of Set 8 | hami
# set = 8
# Processing Record 32 of Set 8 | chanika
# set = 8
# Processing Record 33 of Set 8 | frauenfeld
# set = 8
# Processing Record 34 of Set 8 | poum
# set = 8
# Processing Record 35 of Set 8 | college
# set = 8
# Processing Record 36 of Set 8 | sovetskiy
# set = 8
# Processing Record 37 of Set 8 | minbu
# set = 8
# Processing Record 38 of Set 8 | yangjiang
# set = 8
# Processing Record 39 of Set 8 | soyo
# set = 8
# Processing Record 40 of Set 8 | lasa
# set = 8
# Processing Record 41 of Set 8 | kavaratti
# set = 8
# Processing Record 42 of Set 8 | de aar
# set = 8
# Processing Record 43 of Set 8 | isangel
# set = 8
# Processing Record 44 of Set 8 | surgut
# set = 8
# Processing Record 45 of Set 8 | benjamin hill
# set = 8
# Processing Record 46 of Set 8 | amapa
# set = 8
# Processing Record 47 of Set 8 | namatanai
# set = 8
# Processing Record 48 of Set 8 | hamilton
# set = 8
# Processing Record 49 of Set 8 | akureyri
# set = 8
# Processing Record 50 of Set 8 | ust-ilimsk
# set = 8
# Processing Record 1 of Set 9 | foam lake
# set = 9
# Processing Record 2 of Set 9 | mawlamyine
# set = 9
# Processing Record 3 of Set 9 | lancaster
# set = 9
# Processing Record 4 of Set 9 | felanitx
# set = 9
# Processing Record 5 of Set 9 | newburgh
# set = 9
# Processing Record 6 of Set 9 | ternate
# set = 9
# Processing Record 7 of Set 9 | harrisonville
# set = 9
# Processing Record 8 of Set 9 | sept-iles
# set = 9
# Processing Record 9 of Set 9 | boden
# set = 9
# Processing Record 10 of Set 9 | mentok
# City not found. Skipping...
# set = 9
# Processing Record 11 of Set 9 | gorin
# set = 9
# Processing Record 12 of Set 9 | meyungs
# City not found. Skipping...
# set = 9
# Processing Record 13 of Set 9 | karoi
# set = 9
# Processing Record 14 of Set 9 | sorvag
# City not found. Skipping...
# set = 9
# Processing Record 15 of Set 9 | bilma
# set = 9
# Processing Record 16 of Set 9 | izumo
# set = 9
# Processing Record 17 of Set 9 | mpongwe
# set = 9
# Processing Record 18 of Set 9 | sumbawa
# City not found. Skipping...
# set = 9
# Processing Record 19 of Set 9 | mangulile
# set = 9
# Processing Record 20 of Set 9 | koumac
# set = 9
# Processing Record 21 of Set 9 | zhangye
# set = 9
# Processing Record 22 of Set 9 | manaure
# set = 9
# Processing Record 23 of Set 9 | yulara
# set = 9
# Processing Record 24 of Set 9 | bambous virieux
# set = 9
# Processing Record 25 of Set 9 | erenhot
# set = 9
# Processing Record 26 of Set 9 | ban phaeo
# set = 9
# Processing Record 27 of Set 9 | copiapo
# set = 9
# Processing Record 28 of Set 9 | jabinyanah
# set = 9
# Processing Record 29 of Set 9 | miri
# set = 9
# Processing Record 30 of Set 9 | rolim de moura
# City not found. Skipping...
# set = 9
# Processing Record 31 of Set 9 | saint-ambroise
# set = 9
# Processing Record 32 of Set 9 | chumikan
# set = 9
# Processing Record 33 of Set 9 | mandalgovi
# set = 9
# Processing Record 34 of Set 9 | suhbaatar
# set = 9
# Processing Record 35 of Set 9 | wulanhaote
# City not found. Skipping...
# set = 9
# Processing Record 36 of Set 9 | fazilka
# set = 9
# Processing Record 37 of Set 9 | kathu
# set = 9
# Processing Record 38 of Set 9 | nampula
# set = 9
# Processing Record 39 of Set 9 | tomigusuku
# set = 9
# Processing Record 40 of Set 9 | dubbo
# set = 9
# Processing Record 41 of Set 9 | bokspits
# City not found. Skipping...
# set = 9
# Processing Record 42 of Set 9 | port moresby
# set = 9
# Processing Record 43 of Set 9 | athens
# set = 9
# Processing Record 44 of Set 9 | saryg-sep
# set = 9
# Processing Record 45 of Set 9 | quatre cocos
# set = 9
# Processing Record 46 of Set 9 | riverton
# set = 9
# Processing Record 47 of Set 9 | timbakion
# City not found. Skipping...
# set = 9
# Processing Record 48 of Set 9 | pokhara
# set = 9
# Processing Record 49 of Set 9 | san jeronimo
# set = 9
# Processing Record 50 of Set 9 | beni suef
# set = 9
# Processing Record 1 of Set 10 | acapulco
# set = 10
# Processing Record 2 of Set 10 | ondorhaan
# City not found. Skipping...
# set = 10
# Processing Record 3 of Set 10 | tir pol
# City not found. Skipping...
# set = 10
# Processing Record 4 of Set 10 | ereymentau
# set = 10
# Processing Record 5 of Set 10 | santa vitoria do palmar
# set = 10
# Processing Record 6 of Set 10 | kemi
# set = 10
# Processing Record 7 of Set 10 | halalo
# City not found. Skipping...
# set = 10
# Processing Record 8 of Set 10 | vaitupu
# City not found. Skipping...
# set = 10
# Processing Record 9 of Set 10 | salalah
# set = 10
# Processing Record 10 of Set 10 | raudeberg
# set = 10
# Processing Record 11 of Set 10 | charters towers
# set = 10
# Processing Record 12 of Set 10 | requena
# set = 10
# Processing Record 13 of Set 10 | sao felix do xingu
# set = 10
# Processing Record 14 of Set 10 | hienghene
# set = 10
# Processing Record 15 of Set 10 | ouadda
# set = 10
# Processing Record 16 of Set 10 | cape coral
# set = 10
# Processing Record 17 of Set 10 | dolores
# set = 10
# Processing Record 18 of Set 10 | mnogovershinnyy
# set = 10
# Processing Record 19 of Set 10 | port hawkesbury
# set = 10
# Processing Record 20 of Set 10 | mombetsu
# set = 10
# Processing Record 21 of Set 10 | kenai
# set = 10
# Processing Record 22 of Set 10 | akyab
# set = 10
# Processing Record 23 of Set 10 | wabrzezno
# set = 10
# Processing Record 24 of Set 10 | aklavik
# set = 10
# Processing Record 25 of Set 10 | kondinskoye
# set = 10
# Processing Record 26 of Set 10 | labe
# set = 10
# Processing Record 27 of Set 10 | panuco
# set = 10
# Processing Record 28 of Set 10 | haines junction
# set = 10
# Processing Record 29 of Set 10 | santa rosa
# set = 10
# Processing Record 30 of Set 10 | arlit
# set = 10
# Processing Record 31 of Set 10 | balingen
# set = 10
# Processing Record 32 of Set 10 | lensk
# set = 10
# Processing Record 33 of Set 10 | azimur
# City not found. Skipping...
# set = 10
# Processing Record 34 of Set 10 | satitoa
# City not found. Skipping...
# set = 10
# Processing Record 35 of Set 10 | balintore
# set = 10
# Processing Record 36 of Set 10 | arroyo
# set = 10
# Processing Record 37 of Set 10 | marshall
# set = 10
# Processing Record 38 of Set 10 | hryshkivtsi
# set = 10
# Processing Record 39 of Set 10 | esperance
# set = 10
# Processing Record 40 of Set 10 | melchor de mencos
# set = 10
# Processing Record 41 of Set 10 | pichayevo
# set = 10
# Processing Record 42 of Set 10 | krasnoborsk
# set = 10
# Processing Record 43 of Set 10 | obera
# set = 10
# Processing Record 44 of Set 10 | itaporanga
# set = 10
# Processing Record 45 of Set 10 | le port
# set = 10
# Processing Record 46 of Set 10 | alekseyevsk
# set = 10
# Processing Record 47 of Set 10 | hualmay
# set = 10
# Processing Record 48 of Set 10 | alofi
# set = 10
# Processing Record 49 of Set 10 | zempoala
# set = 10
# Processing Record 50 of Set 10 | teya
# set = 10
# Processing Record 1 of Set 11 | port hardy
# set = 11
# Processing Record 2 of Set 11 | kamaishi
# set = 11
# Processing Record 3 of Set 11 | syzran
# set = 11
# Processing Record 4 of Set 11 | iquique
# set = 11
# Processing Record 5 of Set 11 | colares
# set = 11
# Processing Record 6 of Set 11 | kalomo
# City not found. Skipping...
# set = 11
# Processing Record 7 of Set 11 | hermsdorf
# set = 11
# Processing Record 8 of Set 11 | hobyo
# set = 11
# Processing Record 9 of Set 11 | fort nelson
# set = 11
# Processing Record 10 of Set 11 | dawlatabad
# set = 11
# Processing Record 11 of Set 11 | cherskiy
# set = 11
# Processing Record 12 of Set 11 | acajutla
# set = 11
# Processing Record 13 of Set 11 | tubruq
# City not found. Skipping...
# set = 11
# Processing Record 14 of Set 11 | adre
# set = 11
# Processing Record 15 of Set 11 | sao filipe
# set = 11
# Processing Record 16 of Set 11 | saint-georges
# set = 11
# Processing Record 17 of Set 11 | oda
# set = 11
# Processing Record 18 of Set 11 | ballina
# set = 11
# Processing Record 19 of Set 11 | henties bay
# set = 11
# Processing Record 20 of Set 11 | areka
# set = 11
# Processing Record 21 of Set 11 | forest lake
# set = 11
# Processing Record 22 of Set 11 | tahta
# set = 11
# Processing Record 23 of Set 11 | babu
# set = 11
# Processing Record 24 of Set 11 | ketchikan
# set = 11
# Processing Record 25 of Set 11 | saldanha
# set = 11
# Processing Record 26 of Set 11 | westport
# set = 11
# Processing Record 27 of Set 11 | samalaeulu
# City not found. Skipping...
# set = 11
# Processing Record 28 of Set 11 | zhezkazgan
# set = 11
# Processing Record 29 of Set 11 | eldikan
# City not found. Skipping...
# set = 11
# Processing Record 30 of Set 11 | svetlaya
# set = 11
# Processing Record 31 of Set 11 | kazalinsk
# City not found. Skipping...
# set = 11
# Processing Record 32 of Set 11 | kristiinankaupunki
# set = 11
# Processing Record 33 of Set 11 | na klang
# set = 11
# Processing Record 34 of Set 11 | tabou
# set = 11
# Processing Record 35 of Set 11 | notre-dame-du-lac
# set = 11
# Processing Record 36 of Set 11 | sioux falls
# set = 11
# Processing Record 37 of Set 11 | volsk
# set = 11
# Processing Record 38 of Set 11 | necochea
# set = 11
# Processing Record 39 of Set 11 | zyryanka
# set = 11
# Processing Record 40 of Set 11 | tiarei
# set = 11
# Processing Record 41 of Set 11 | folsom
# set = 11
# Processing Record 42 of Set 11 | erzincan
# set = 11
# Processing Record 43 of Set 11 | port lincoln
# set = 11
# Processing Record 44 of Set 11 | mastic beach
# set = 11
# Processing Record 45 of Set 11 | tsurugi
# set = 11
# Processing Record 46 of Set 11 | mayo
# set = 11
# Processing Record 47 of Set 11 | khovu-aksy
# set = 11
# Processing Record 48 of Set 11 | kananga
# set = 11
# Processing Record 49 of Set 11 | cabra
# set = 11
# Processing Record 50 of Set 11 | derzhavinsk
# set = 11
# Processing Record 1 of Set 12 | mayor pablo lagerenza
# set = 12
# Processing Record 2 of Set 12 | saleaula
# City not found. Skipping...
# set = 12
# Processing Record 3 of Set 12 | khor
# set = 12
# Processing Record 4 of Set 12 | salaspils
# set = 12
# Processing Record 5 of Set 12 | thunder bay
# set = 12
# Processing Record 6 of Set 12 | najran
# set = 12
# Processing Record 7 of Set 12 | touros
# set = 12
# Processing Record 8 of Set 12 | la joya
# set = 12
# Processing Record 9 of Set 12 | pochutla
# set = 12
# Processing Record 10 of Set 12 | severnyy
# set = 12
# Processing Record 11 of Set 12 | san cristobal
# set = 12
# Processing Record 12 of Set 12 | kiama
# set = 12
# Processing Record 13 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# set = 12
# Processing Record 14 of Set 12 | progreso
# set = 12
# Processing Record 15 of Set 12 | yelizovo
# set = 12
# Processing Record 16 of Set 12 | kosonsoy
# set = 12
# Processing Record 17 of Set 12 | kamenskoye
# City not found. Skipping...
# set = 12
# Processing Record 18 of Set 12 | port-gentil
# set = 12
# Processing Record 19 of Set 12 | tongling
# set = 12
# Processing Record 20 of Set 12 | da lat
# set = 12
# Processing Record 21 of Set 12 | port-de-paix
# City not found. Skipping...
# set = 12
# Processing Record 22 of Set 12 | fujin
# set = 12
# Processing Record 23 of Set 12 | krasnozerskoye
# set = 12
# Processing Record 24 of Set 12 | awjilah
# set = 12
# Processing Record 25 of Set 12 | eureka
# set = 12
# Processing Record 26 of Set 12 | takhli
# set = 12
# Processing Record 27 of Set 12 | turbat
# set = 12
# Processing Record 28 of Set 12 | palabuhanratu
# City not found. Skipping...
# set = 12
# Processing Record 29 of Set 12 | umzimvubu
# City not found. Skipping...
# set = 12
# Processing Record 30 of Set 12 | yibin
# set = 12
# Processing Record 31 of Set 12 | dourdan
# set = 12
# Processing Record 32 of Set 12 | celestun
# set = 12
# Processing Record 33 of Set 12 | iquitos
# set = 12
# Processing Record 34 of Set 12 | durant
# set = 12
# Processing Record 35 of Set 12 | aconibe
# set = 12
# Processing Record 36 of Set 12 | kalat
# set = 12
# Processing Record 37 of Set 12 | nieuw nickerie
# set = 12
# Processing Record 38 of Set 12 | sagarejo
# set = 12
# Processing Record 39 of Set 12 | karkaralinsk
# City not found. Skipping...
# set = 12
# Processing Record 40 of Set 12 | takestan
# set = 12
# Processing Record 41 of Set 12 | camana
# set = 12
# Processing Record 42 of Set 12 | amahai
# set = 12
# Processing Record 43 of Set 12 | madison heights
# set = 12
# Processing Record 44 of Set 12 | novokruchininskiy
# set = 12
# Processing Record 45 of Set 12 | kleck
# City not found. Skipping...
# set = 12
# Processing Record 46 of Set 12 | kashi
# set = 12
# Processing Record 47 of Set 12 | istiaia
# set = 12
# Processing Record 48 of Set 12 | rocky mountain house
# set = 12
# Processing Record 49 of Set 12 | hovd
# set = 12
# Processing Record 50 of Set 12 | palmer
# set = 12
# Processing Record 1 of Set 13 | kuvshinovo
# set = 13
# Processing Record 2 of Set 13 | yorkton
# set = 13
# Processing Record 3 of Set 13 | amalapuram
# set = 13
# Processing Record 4 of Set 13 | gisborne
# set = 13
# Processing Record 5 of Set 13 | tessalit
# set = 13
# Processing Record 6 of Set 13 | baisha
# set = 13
# Processing Record 7 of Set 13 | neuquen
# set = 13
# Processing Record 8 of Set 13 | tebingtinggi
# set = 13
# Processing Record 9 of Set 13 | zabid
# set = 13
# Processing Record 10 of Set 13 | san-pedro
# set = 13
# Processing Record 11 of Set 13 | araouane
# set = 13
# Processing Record 12 of Set 13 | mariental
# set = 13
# Processing Record 13 of Set 13 | bichena
# set = 13
# Processing Record 14 of Set 13 | deputatskiy
# set = 13
# Processing Record 15 of Set 13 | kangaatsiaq
# set = 13
# Processing Record 16 of Set 13 | bad durrenberg
# set = 13
# Processing Record 17 of Set 13 | keetmanshoop
# set = 13
# Processing Record 18 of Set 13 | yatou
# set = 13
# Processing Record 19 of Set 13 | ust-kut
# set = 13
# Processing Record 20 of Set 13 | kassala
# set = 13
# Processing Record 21 of Set 13 | cambridge
# set = 13
# Processing Record 22 of Set 13 | lufilufi
# set = 13
# Processing Record 23 of Set 13 | novyy urengoy
# set = 13
# Processing Record 24 of Set 13 | vrangel
# set = 13
# Processing Record 25 of Set 13 | balabac
# set = 13
# Processing Record 26 of Set 13 | pringsewu
# set = 13
# Processing Record 27 of Set 13 | kaeo
# set = 13
# Processing Record 28 of Set 13 | onguday
# set = 13
# Processing Record 29 of Set 13 | timmins
# set = 13
# Processing Record 30 of Set 13 | asau
# set = 13
# Processing Record 31 of Set 13 | high level
# set = 13
# Processing Record 32 of Set 13 | boa vista
# set = 13
# Processing Record 33 of Set 13 | bonavista
# set = 13
# Processing Record 34 of Set 13 | hervey bay
# set = 13
# Processing Record 35 of Set 13 | buzdyak
# set = 13
# Processing Record 36 of Set 13 | zhanaozen
# set = 13
# Processing Record 37 of Set 13 | arauca
# set = 13
# Processing Record 38 of Set 13 | karratha
# set = 13
# Processing Record 39 of Set 13 | gannan
# set = 13
# Processing Record 40 of Set 13 | novichikha
# set = 13
# Processing Record 41 of Set 13 | vestmannaeyjar
# set = 13
# Processing Record 42 of Set 13 | guerrero negro
# set = 13
# Processing Record 43 of Set 13 | axim
# set = 13
# Processing Record 44 of Set 13 | maraial
# set = 13
# Processing Record 45 of Set 13 | fandriana
# set = 13
# Processing Record 46 of Set 13 | saint-augustin
# set = 13
# Processing Record 47 of Set 13 | kenora
# set = 13
# Processing Record 48 of Set 13 | vega de alatorre
# set = 13
# Processing Record 49 of Set 13 | egvekinot
# set = 13
# Processing Record 50 of Set 13 | oranjemund
# set = 13
# Processing Record 1 of Set 14 | dom pedrito
# set = 14
# Processing Record 2 of Set 14 | marsa matruh
# set = 14
# Processing Record 3 of Set 14 | ulfborg
# set = 14
# Processing Record 4 of Set 14 | marawi
# set = 14
# Processing Record 5 of Set 14 | mangaratiba
# set = 14
# Processing Record 6 of Set 14 | nemuro
# set = 14
# Processing Record 7 of Set 14 | anadyr
# set = 14
# Processing Record 8 of Set 14 | krasnaya gora
# set = 14
# Processing Record 9 of Set 14 | volot
# set = 14
# Processing Record 10 of Set 14 | puerto ayacucho
# set = 14
# Processing Record 11 of Set 14 | doha
# set = 14
# Processing Record 12 of Set 14 | atar
# set = 14
# Processing Record 13 of Set 14 | witu
# set = 14
# Processing Record 14 of Set 14 | phan rang
# City not found. Skipping...
# set = 14
# Processing Record 15 of Set 14 | vila velha
# set = 14
# Processing Record 16 of Set 14 | rudnya
# set = 14
# Processing Record 17 of Set 14 | yar-sale
# set = 14
# Processing Record 18 of Set 14 | sinazongwe
# set = 14
# Processing Record 19 of Set 14 | tlahualilo
# City not found. Skipping...
# set = 14
# Processing Record 20 of Set 14 | leshukonskoye
# set = 14
# Processing Record 21 of Set 14 | agadez
# set = 14
# Processing Record 22 of Set 14 | yerbogachen
# set = 14
# Processing Record 23 of Set 14 | cartagena
# set = 14
# Processing Record 24 of Set 14 | jacala
# set = 14
# Processing Record 25 of Set 14 | zverinogolovskoye
# set = 14
# Processing Record 26 of Set 14 | gazanjyk
# set = 14
# Processing Record 27 of Set 14 | terney
# set = 14
# Processing Record 28 of Set 14 | whitehorse
# set = 14
# Processing Record 29 of Set 14 | chifeng
# set = 14
# Processing Record 30 of Set 14 | sisimiut
# set = 14
# Processing Record 31 of Set 14 | turukhansk
# set = 14
# Processing Record 32 of Set 14 | bourges
# set = 14
# Processing Record 33 of Set 14 | liuzhou
# set = 14
# Processing Record 34 of Set 14 | baiyin
# set = 14
# Processing Record 35 of Set 14 | fukue
# set = 14
# Processing Record 36 of Set 14 | gull lake
# set = 14
# Processing Record 37 of Set 14 | arivonimamo
# set = 14
# Processing Record 38 of Set 14 | tanout
# set = 14
# Processing Record 39 of Set 14 | aasiaat
# set = 14
# Processing Record 40 of Set 14 | sobolevo
# set = 14
# Processing Record 41 of Set 14 | ozgon
# City not found. Skipping...
# set = 14
# Processing Record 42 of Set 14 | mocambique
# City not found. Skipping...
# set = 14
# Processing Record 43 of Set 14 | chumphon
# set = 14
# Processing Record 44 of Set 14 | corsicana
# set = 14
# Processing Record 45 of Set 14 | serra talhada
# set = 14
# Processing Record 46 of Set 14 | vestmanna
# set = 14
# Processing Record 47 of Set 14 | bam
# set = 14
# Processing Record 48 of Set 14 | upington
# set = 14
# Processing Record 49 of Set 14 | vuktyl
# set = 14
# Processing Record 50 of Set 14 | mukhtolovo
# set = 14
# Processing Record 1 of Set 15 | pacific grove
# set = 15
# Processing Record 2 of Set 15 | bodden town
# set = 15
# Processing Record 3 of Set 15 | dano
# set = 15
# Processing Record 4 of Set 15 | gaspe
# set = 15
# Processing Record 5 of Set 15 | utiroa
# City not found. Skipping...
# set = 15
# Processing Record 6 of Set 15 | pietarsaari
# set = 15
# Processing Record 7 of Set 15 | nabire
# set = 15
# Processing Record 8 of Set 15 | saint-louis
# set = 15
# Processing Record 9 of Set 15 | tatarsk
# set = 15
# Processing Record 10 of Set 15 | sarakhs
# set = 15
# Processing Record 11 of Set 15 | samusu
# City not found. Skipping...
# set = 15
# Processing Record 12 of Set 15 | praia
# set = 15
# Processing Record 13 of Set 15 | calama
# set = 15
# Processing Record 14 of Set 15 | haibowan
# City not found. Skipping...
# set = 15
# Processing Record 15 of Set 15 | dharchula
# set = 15
# Processing Record 16 of Set 15 | hambantota
# set = 15
# Processing Record 17 of Set 15 | sivas
# set = 15
# Processing Record 18 of Set 15 | chagda
# City not found. Skipping...
# set = 15
# Processing Record 19 of Set 15 | barcelos
# set = 15
# Processing Record 20 of Set 15 | hay river
# set = 15
# Processing Record 21 of Set 15 | norden
# set = 15
# Processing Record 22 of Set 15 | alyangula
# set = 15
# Processing Record 23 of Set 15 | anchorage
# set = 15
# Processing Record 24 of Set 15 | male
# set = 15
# Processing Record 25 of Set 15 | date
# set = 15
# Processing Record 26 of Set 15 | umm lajj
# set = 15
# Processing Record 27 of Set 15 | ureki
# set = 15
# Processing Record 28 of Set 15 | hit
# set = 15
# Processing Record 29 of Set 15 | atherton
# set = 15
# Processing Record 30 of Set 15 | outjo
# set = 15
# Processing Record 31 of Set 15 | green river
# set = 15
# Processing Record 32 of Set 15 | baiao
# set = 15
# Processing Record 33 of Set 15 | collie
# set = 15
# Processing Record 34 of Set 15 | da nang
# set = 15
# Processing Record 35 of Set 15 | istria
# set = 15
# Processing Record 36 of Set 15 | dalvik
# set = 15
# Processing Record 37 of Set 15 | gidole
# set = 15
# Processing Record 38 of Set 15 | porangatu
# set = 15
# Processing Record 39 of Set 15 | sitka
# set = 15
# Processing Record 40 of Set 15 | shizunai
# set = 15
# Processing Record 41 of Set 15 | volosovo
# set = 15
# Processing Record 42 of Set 15 | ode
# set = 15
# Processing Record 43 of Set 15 | shestakovo
# set = 15
# Processing Record 44 of Set 15 | tombouctou
# set = 15
# Processing Record 45 of Set 15 | bathsheba
# set = 15
# Processing Record 46 of Set 15 | tawau
# set = 15
# Processing Record 47 of Set 15 | kolokani
# set = 15
# Processing Record 48 of Set 15 | salvador
# set = 15
# Processing Record 49 of Set 15 | puerto cabezas
# set = 15
# Processing Record 50 of Set 15 | vostok
# set = 15
# Processing Record 1 of Set 16 | caarapo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 688

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df = city_data_df.drop(columns =["Date"])
city_data_df.head(10)
# Out:
#                         City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Severo-Kurilsk      RU  50.6789  156.1250     56.34        88
# 1                  Busselton      AU -33.6500  115.3333     51.26        84
# 2                     Hobart      AU -42.8794  147.3294     46.26        83
# 3                     Killin      US  33.6123  -91.7412     93.29        52
# 4                     Padang      ID  -0.9492  100.3543     69.85        73
# 5  Petropavlovsk-Kamchatskiy      RU  53.0452  158.6483     59.59        94
# 6                  Mahebourg      MU -20.4081   57.7000     67.24        66
# 7                 Bredasdorp      ZA -34.5322   20.0403     53.89        86
# 8                     Barrow      US  71.2906 -156.7887     42.82        81
# 9                Provideniya      RU  64.3833 -173.3000     44.71        81
#
#    Cloudiness  Wind Speed Current Description
# 0          99        9.84     overcast clouds
# 1           0        7.67           clear sky
# 2          75       11.50       broken clouds
# 3           0        5.75           clear sky
# 4          39        4.05    scattered clouds
# 5         100        6.71     overcast clouds
# 6          56       24.25          light rain
# 7         100        1.92     overcast clouds
# 8         100       18.41          light rain
# 9          75       18.01       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
